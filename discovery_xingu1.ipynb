# %% [markdown]
# # Discovery Report: Potential Pre-Columbian Site Along the Rio Xingu
#
# **Author**: Yuval Vizentovski
# **Submitted to**: OpenAI to Z Challenge, 2025
# **Region**: Northern Mato Grosso, Brazil — Xingu River Biome
# **Coordinates**: Latitude ~ -13.0, Longitude ~ -52.9
# **Date of Satellite Imagery**: 2025-05-24
# **DEM Source**: Copernicus GLO-30 via OpenTopography
# **Satellite Source**: Sentinel-2 L2A via Copernicus Browser
#
# ---
#
# ## 🔍 Summary
#
# This notebook documents the discovery of terrain anomalies and visual patterns consistent with pre-Columbian engineered landscapes in the Amazon. Using elevation and optical imagery, we identify a promising region along the Rio Xingu for potential archaeological relevance.

# %%
from PIL import Image
import matplotlib.pyplot as plt

elevation = Image.open("vision-ready-map.png")
satellite = Image.open("sat_zoom1.jpg")

fig, axs = plt.subplots(1, 2, figsize=(18, 9))

axs[0].imshow(elevation)
axs[0].set_title("Amazon Elevation Anomaly Map (Copernicus DEM)")
axs[0].axis("off")

axs[1].imshow(satellite)
axs[1].set_title("Rio Xingu River Bend (Sentinel-2, 2025-05-24)")
axs[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧠 AI Observations
#
# ### 1. Elevation Analysis
# - Southern quadrant reveals sharp rectilinear voids in canopy.
# - Elevation levels flatten in a central zone (~360–380m), suggesting platform construction or earth mounding.
# - River-adjacent mounds are visible in both DEM and satellite overlay.
#
# ### 2. Satellite Pattern Recognition
# - Vegetation disruption detected inside river meander.
# - Shoreline cut with unnatural right-angled geometry, inconsistent with erosion.
# - Possible "platform" or artificially elevated zone mid-meander.
#
# ---
#
# ## 🧬 Hypothesis
#
# This terrain shows indications of anthropogenic alteration:
# - Regular geometry in elevation and land clearing
# - Riverbank shaping
# - Central mound-like structure with strategic placement
#
# These findings suggest:
# - A potential **settlement site**, **ceremonial platform**, or **agricultural terrace system** likely associated with a pre-Columbian civilization.
#
# ---
#
# ## 📚 Sources
#
# - Copernicus Global Digital Elevation Model (2024), ESA: [https://doi.org/10.5069/G9028PQB](https://doi.org/10.5069/G9028PQB)
# - Sentinel-2 Imagery (2025), Copernicus Browser: [https://dataspace.copernicus.eu/](https://dataspace.copernicus.eu/)
# - OpenTopography DTM API Access: [https://opentopography.org/](https://opentopography.org/)
